# %%
"""
View parquet file as DataFrame using Polars
"""

import polars as pl
from pathlib import Path

# Read the latest parquet file
file_path = "/Users/hieudt/edgar-analysis-project/outputs"

# Read file using Polars
df = pl.read_parquet(file_path)

# Display data
df[0:1]
# Out:
# shape: (1, 8)
# ┌──────┬─────────────┬────────────┬────────────┬───────────┬─────────────┬────────────┬────────────┐
# │ year ┆ filename    ┆ cik        ┆ filed_date ┆ form_type ┆ conformed_p ┆ item_1a    ┆ item_7     │
# │ ---  ┆ ---         ┆ ---        ┆ ---        ┆ ---       ┆ eriod       ┆ ---        ┆ ---        │
# │ str  ┆ str         ┆ str        ┆ str        ┆ str       ┆ ---         ┆ str        ┆ str        │
# │      ┆             ┆            ┆            ┆           ┆ str         ┆            ┆            │
# ╞══════╪═════════════╪════════════╪════════════╪═══════════╪═════════════╪════════════╪════════════╡
# │ 2024 ┆ 20240627_10 ┆ 0001630113 ┆ 20240627   ┆ 10-K      ┆ 20240331    ┆ ITEM       ┆ ITEM       │
# │      ┆ -K_edgar_da ┆            ┆            ┆           ┆             ┆ 1A. RISK   ┆ 7.         │
# │      ┆ ta_16301…   ┆            ┆            ┆           ┆             ┆ FACTORS    ┆ MANAGEMENT │
# │      ┆             ┆            ┆            ┆           ┆             ┆            ┆ S          │
# │      ┆             ┆            ┆            ┆           ┆             ┆ Risks      ┆ DISCUSSIO… │
# │      ┆             ┆            ┆            ┆           ┆             ┆ …          ┆            │
# └──────┴─────────────┴────────────┴────────────┴───────────┴─────────────┴────────────┴────────────┘
